# %% [markdown]
# # Hello, Python
# A quick introduction to Python syntax, variable assignment, and numbers

# %% [markdown]
# This course covers the key Python skill you'll need so you can start using Python for data science.
# The course is ideal for someone with some previous coding experience who wants to add Python to their repertorire.
# (If you're a first-time coder, you are encourged to check out our Intro to Programming course, which is designed for complete beginners who would like to get started with Python.)
#
# We'll start with a brief overview of Python sytax, variable assignment, and arithmetic operators.
#
# 訳）このコースでは、データサイエンスでPythonを使い始めるために必要となる、重要なPythonスキルを学びます。
# このコースは多少のコーディング経験があり、新たにPythonをスキルセットに加えてたい方に最適です。
# （初めてコーディングする場合、Pythonを始める完全初心者向け設計された「Intro to Programming」コースを受講することをお勧めします。）
#
# まず、Pythonの構文、変数の代入、、算術演算子について、簡単な概要から始めます。

# %% [markdown]
# ## Hello, Python!
# Python was named for the British comedy troupe Monty Python, so we'll make our first Python program a homage to their skit about Spam.
# Just for fun, try reading over the code below and prediciting what it's going to do when run.
# (if you have no idea, that's fine!)
# Then click the "output" button to see the results of our program.
#
# 訳)Pythonは英国劇団の「モンティパイソン」から名付けられました。そこで、最初のPythonプログラムは彼らの「Spam」に関するコントへのオマージュを作ります。
# ちょっとしたお遊びとして、まずは下のコードをざっと読んでみて、実行すると何が起きるか予想してください。
# （分からなくても全然問題ありません。）
# その後、"output"ボタンをクリックしプログラムの結果を確認しましょう。

# %%
spam_amount = 0
print(spam_amount)

# Ordering Spam, egg, Spam, bacon, and Spam (4 more servings of Spam)
spam_amount = spam_amount + 4

if spam_amount > 0:
    print("But I don't wnt ANY spam")

viking_song = "Spam " * spam_amount
print(viking_song)
# Out:
# 0
# But I don't wnt ANY spam
# Spam Spam Spam Spam

# %% [markdown]
# There's a lot to unpack here!
# This silly program demonstrates many important aspects of what Python code looks like and how it works.
# Let's review the code from top to bottom.
#
# 訳）ここには、説明すべき点がたくさんあります。
# このちょっとしたプログラムは、Pythonコードの書き方や、どのように動作するかといった重要なポイントを数多く示しています。
# 上から下まで順にコードを確認しましょう。

# %%
spam_amount = 0

# %% [markdown]
# **Variable assignment:** Here we create a variable called spam_amount and assign it the value of 0 using = , which is called the assignment operator.
#
# **Note**: if you've programmed in certain other languages (like Java or C++), you might be noticing some things Python doesn't require us to do here.
# - we don't need to "declare" spam_amount berfore assigning to it
# - we don't need to tell Python what type of value spam_amount is going to refer to. In fact, we can even go on to reassign spam_amount to refer to a different sort of thing like a string or a boolean.
#
# 訳)**変数の代入:** ここでは、spam_amountという変数を作成し、代入演算子=を使用して0の値を代入します。
#
# **注釈**:　JavaやC++のような他の言語でプログラミングしたことがある場合と、Pythonではいくつかのことが不要になります。
# - spam_amountを代入する前に、"宣言"する必要がありません。
# - spam_amountの値がどのような型を参照するかを、あらかじめPythonに伝える必要もありません。実際にspam_amountに文字列や真偽値のような異なる型を第代入することもできます。

# %%
print(spam_amount)
# Out:
# 0

# %% [markdown]
# **Function calls:** print is a Python function that displays the value passed to it on the screen.
# We call functions by putting parentheses after their name, and putting the inputs (or arguments) to the function in those parentheses.
#
# 訳）**関数の呼び出し:** printは画面に値を表示するPythonの関数です。
# 関数は、関数名の後に括弧を付け、その中に入力値(引数)を書くことで呼び出します。

# %%
# Ordering Spam, egg, Spam, Spam, becon, and Spam (4 more servings of Spam)
spam_amount = spam_amount + 4

# %% [markdown]
# The first line above is a comment.
# In Python, comments begin with the # symbol.
#
# Next we see an example of reassignment.
# Reassigning the value of an existing variable looks just the same as creating a variable it still uses the = assignment operator.
#
# In the case, the value we're assgining to spam_amount involves some simple arithmetic on its previous value.
# When it encounters this line, Python evaluates the expression on the right-hand-side of the = (0+4=4), and then assigns that value to the variable on the left-hand-side.
#
# 訳）上の1行目はコメントです。
# Pythonでは、コメントは#記号で始まります。
#
# 次は再代入する例を見てみましょう。
# すでに存在する変数に再代入する値は変数を作成したときと同じように代入演算子＝を使用します。
#
# この場合、spam_amountに代入している値は前の値を使った単純な計算になっています。
# この行が実行されると、Pythonは=の右辺に書いた(0+4=4)を評価し、その結果を左辺の変数に代入します。

# %%
if spam_amount > 0:
    print("But I don't want ANY spam!")

viking_song = "Spam Spam Spam"
print(viking_song)
# Out:
# But I don't want ANY spam!
# Spam Spam Spam

# %% [markdown]
# We won't talk much about "conditionals" until later, but, even if you've never coded before, you can probably guess what this does.
# Python is prized for its readability and the simplicity.
#
# Note how we indicated which code belongs to the if.
# "But I don't want ANY spam!" is only supposed to be printed if spam_amount is positive.
# But the later code (like print (viking_song)) should be executed no matter what.
# How do we (and Python) know that?
#
# The colon (:) at the end of the if line indicates that a new code block is starting.
# Subsequent lines  which are indented are part of that code block.
#
# **Note**: If you're coded before, you might know that some other languages use {curly braces} to mark the beginning and end of code blocks.
# Python's use of meaningful whitespace can be surprising to programmers who are accustomed to other languages, but in practice it can lead to more consistent and readable code than languages that do not enforce indentation of code blocks.
#
# The later lines dealing with viking_song are not indented with an extra 4 spaces, so they're not a part of the if's code block.
# We'll see more examples of indented code blocks later when we define functions and using loops.
#
# This code snippet is also our first sighting of a **string** in Python:
#
# 訳）ここでは"条件分岐"についてまだ詳しく説明しませんが、これまで1度もコーディングしたことがなくても、これが何をするかおそらく推測できるでしょう。
# Pythonはコードの可読性やシンプルさで高く評価されています。
#
# ifにどのコードが属しているか注目してください。
# spma_amountが正の場合のみ、"But I don't want ANY spam!"が出力されます。
# しかし、(viking_songのような)後のコードは問題なく実行されるべきです。
# どのようにPythonが判断しているでしょうか？
#
# if行末尾のコロン(:)は新しいコードのかたまりが始まることを示しています。
# インデントされた次の行はコードのかたまりの一部です。
#
# **注釈:**　コーディングの経験がある方は、他の言語ではコードの始まりや終わりを示すために{波括弧}を使用するとご存知かもしれません。
# Pythonでは意味のある空白を用いるため、他の言語で慣れているプログラマーは驚かれるでしょう。
# しかし、実際には、インデントを強制しない言語よりも、一貫性があり読みやすいコードにつながることが多いです。
#
# viking_songを扱う後の行は、4つの余白がインデントされてないです。そのため、ifコードのかたまりの一部ではありません。
# 関数を定義したり、繰り返しを使用する場合に、インデントされたコードのかたまりの例をたくさん見るでしょう。
#
# このコードはPythonで**文字列**を初めて見ることになります。

# %%
"But I don't want ANY spam!"
# Out:
# "But I don't want ANY spam!"

# %% [markdown]
# String can be marked either by double or single quotation marks.
# (But because this particular string contains a single-quote character, we might confuse Python by trying to surround it with single-quotes, unless we're careful.)
#
# 訳）文字列はダブルクォートもしくはシングルクォートで囲んで表します。
# （ただし、この例のようにシングルクォート文字を含む文字列を、注意せずにシングルクォートで囲むと、Pythonは正しく解釈できずエラーになるかもしれません。）

# %%
viking_song = "Spam " * spam_amount
print(viking_song)
# Out:
# Spam Spam Spam Spam

# %% [markdown]
# The * operator can be used to multiply two numbers (3 * 3 evaluates to 9), but we can also multiply a string by a number, to get a version that's been repeated that many times.
# Python offers a number of cheeky little time-saving tricks like this where operators like * and + have a different meaning depending on what kind of thing they're applied to.
# (The technical term for this is operator overloading.)
#
# 訳）*演算子は2つの数字を掛け算するために使用しますが、文字列に数字を掛けることで、その文字列を指定した回数だけ繰り返さえした文字列を得ることもできます。
# Pythonはこのように、*や+といった演算子が適用される対象の方によって異なる意味を持つという、便利な省力的な仕組みが数多く用意されています。（この技術用語は演算子オーバーローディングです。）

# %% [markdown]
# ## Numbers and arithmetic in Python
#
# We've already seen an example of a variable containing a number above:

# %%
spam_amount = 0

# %% [markdown]
# The * operator can be used to multiply tow numbers (3 * 3 evaluates to 9), but we can also multiply a string by a number, to get a version that's been repreated that many times.
# Python offers a number of cheeky little time-saving tricks like this where operators like * and + have a different meaning depending on what kind of thing they're applied to.
# (The technical term for this is operator overloading.)
#
# 訳）*演算子は2つの数字を掛け算するために使用しますが、文字列が何回も繰り返される形式を得るために、数字を指定して文字列は複数にできます。
# Pythonはこのような時短テクニックを数多く提供します。また+は適用される型によって異なる意味を持ちます。（この技術用語は演算子オーバーローディングです。）

# %%
spam_amount = 0

# %% [markdown]
# "Number" is a fine informal name for the kind of thing, but if we wanted to be more technical, we could ask Python how it would describe the type of thing that spam_amount is:
#
# 訳）"Number"はその種のものを表す一般的な呼び方ですが、より技術的に表現したい場合、spam_amountがどのような型として扱われているかをPythonに尋ねることができます。

# %%
type(spam_amount)
# Out:
# int

# %% [markdown]
# It's an int -short for integer. There's another sort of number we commonly encounter in Python:

# %%
type(19.95)
# Out:
# float

# %% [markdown]
# A float is a number with a decimal place-very useful for representing things like weight or proportions.
#
# type() is the second built-in function we've seen (after print()), and it's anoter good one to remember.
# It's very useful to be able to ask Python "what kind of thing is this?".
#
# A natural thing to want to do with numbers is perform arithmetic.
# We've seen the + operator for addition, and the * operator for multiplication.
# Python also has us covered for the rest of the basic buttons on your calculator:
#
# One interesting observation here is that, whereas your calculator probably just has one button for division, Python can do two kind.
# "True division" is basically what your calculator does:
#
# 訳）浮動小数点数は小数点を含む数値のことで、重量や割合のような値を表記するのに非常に便利です。
# type()はこれまで登場した組み込み関数のうちprint()に続く2つ目の関数で、覚えておくととても役立ちます。
# Pythonに対して「これはどのような型のオブジェクトですか？」と尋ねることは非常に有用です。
#
# 数字に対して行いたい自然な操作の1つは算出演算です。
# 足し算は+演算子、掛け算は*演算子であるとすでに見てきました。
# Pythonは電卓にあるその他の基本ボタンをすべてを取り扱います。
#
# ここの興味深い点の1つは、電卓には割り算のボタンが1つ種類しかないのに対し、Pythonは2種類の割り算かできることです。
# "真の割り算"は基本的に電卓と同じ動作をします。

# %%
print(5/2)
print(6/2)
# Out:
# 2.5
# 3.0

# %% [markdown]
# It always gives us a float.
# The // operator give us a result that's rounded down to the next integer.

# %%
print(5//2)
print(6//2)
# Out:
# 2
# 3

# %% [markdown]
# Can you think of where this would be useful?
# You'll see an example soon in the coding challenge.

# %% [markdown]
# ## Order of operations
#
# The arithemetic we learned in primary school has conventions about the order in which operations are evaluated.
# Some remember these by a mnemonic such as **PEMDAS** - **P**arenthese, **E**xponents, **M**ultiplication/**D**ivision, **A**dition/**S**ubtraction.
#
# Python follows similar rules about which calculations to perform first.
# They're mostly pretty intuitive.
#
# 訳）小学校で学んだ算術演算では、どの演算をどの順序で計算するかについて一定の決まりがありました。
# それはPEMDAS(括弧、指数、掛け算/割り算、足し算/引き算)といった語呂合わせで覚えている人もいます。
#
# Pythonでも、どの計算を最初に実行するかこれらと似たルールに従います。
# それらはほとんど直感的に理解できます。

# %%
8-3+2
# Out:
# 7

# %%
-3+4*2
# Out:
# 5

# %% [markdown]
# Sometimes the default order of operations isn't what we want:

# %%
hat_height_cm = 25
my_height_cm = 190
# How tall am I, in meters, when wearing my hat?
total_height_meters = hat_height_cm + my_height_cm /100
print("Height in meters =", total_height_meters, "?")
# Out:
# Height in meters = 26.9 ?

# %% [markdown]
# Parentheses are useful here.
# You can add them to force Python to evaluate sub-expressions in whatever order you want.

# %%
total_height_meters = (hat_height_cm + my_height_cm)/100
print("Height in meters =", total_height_meters)
# Out:
# Height in meters = 2.15

# %% [markdown]
# ## Builtin functions for working with numbers
#
# min and max return the minimum and maximum of their arguments, respectively...

# %%
print(min(1,2,3))
print(max(1,2,3))
# Out:
# 1
# 3

# %% [markdown]
# abs returns the absolute value of an argument.

# %%
print(abs(32))
print(abs(-32))
# Out:
# 32
# 32

# %% [markdown]
# In addition to being the names of Python's two main numerical types, int and float can also be called as functions which convert their arguments to the corresponding type:

# %%
print(float(10))
print(int(3.33))
# They can even be called on string!
print(int('807')+1)
# Out:
# 10.0
# 3
# 808
